# %% [markdown]
# # Schelling Model
#
# * to demonstrate grid-based discrete space

# %%
from mesa.examples.basic.schelling.app import page
page
# Out:
# Model initialised with homophly 0.4
# Cannot show ipywidgets in text
